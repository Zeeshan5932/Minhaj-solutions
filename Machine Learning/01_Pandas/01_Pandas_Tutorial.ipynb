# %% [markdown]
# # Pandas Tutorial: Complete Guide
#
# This notebook follows a step-by-step learning flow for Pandas.
#
# ## Topics in Order
# 1. Series & DataFrame - basic data structures
# 2. Data Loading - CSV, JSON, Excel read/write
# 3. Data Exploration - `head()`, `info()`, `describe()`
# 4. Indexing & Selection - `loc`, `iloc`
# 5. Data Cleaning - null values, duplicates
# 6. Groupby & Aggregation
# 7. Merging & Joining DataFrames
#
# Pandas is a fast, powerful, and easy-to-use open-source data analysis and manipulation library built on top of Python. It is widely used in Machine Learning and Data Science workflows.
#
# **Why use Pandas?**
# - Efficient data manipulation and analysis.
# - Handles structured data easily (CSV, JSON, Excel, SQL, etc.).
# - Essential for data preprocessing in ML workflows.
#
# **Importance in ML:**
# - Data cleaning: handle missing values and duplicates.
# - Feature engineering: create new features from existing data.
# - Data exploration: summarize and visualize datasets quickly.

# %% [markdown]
# ## 1. Series & DataFrame
#
# Pandas ke do basic data structures yeh hain:
# - `Series`: one-dimensional labeled data
# - `DataFrame`: two-dimensional table with rows and columns
#
# Is section mein hum dekhain ge ke series aur dataframe kaise create hote hain aur kaise print kiye jate hain.

# %%
import pandas as pd
print('Pandas Version:', pd.__version__)
# Out:
# Pandas Version: 2.2.3

# %%
# Creating Series
series_from_list = pd.Series([10, 20, 30, 40, 50], name='zeeshan')
series_from_dict = pd.Series({'a':100,'b':200,'c':300}, name='DictSeries')
print(series_from_list)
print(series_from_dict)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: zeeshan, dtype: int64
# a    100
# b    200
# c    300
# Name: DictSeries, dtype: int64

# %%
# Creating DataFrames
data = {
    'Name': ['Alice','Bob','Charlie','David'],
    'Age': [25,30,35,40],
    'City': ['New York','Los Angeles','Chicago','Houston']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# ## 2. Data Loading
#
# Pandas multiple file formats ko support karta hai:
# - `read_csv()` for CSV files
# - `read_json()` for JSON files
# - `read_excel()` / `to_excel()` for Excel workbooks
#
# Neeche sample `data/` folder ke actual files use kiye gaye hain.

# %%
# Read CSV from the sample data folder
csv_path = './data/dummy_students.csv'
df_csv = pd.read_csv(csv_path)

# %%
df_csv.head()
# Out:
#    StudentID    Name  Age Grade       City
# 0        101     Ali   20     A     Lahore
# 1        102    Sara   21     B    Karachi
# 2        103   Ahmed   19     A  Islamabad
# 3        104    Zara   22     C     Multan
# 4        105  Hassan   20     B   Peshawar

# %%
# Read JSON from the sample data folder
json_path = './data/dummy_students.json'
df_json = pd.read_json(json_path)

# %%
import pandas as pd

# Read the Excel file (adjust path if needed)
df = pd.read_excel('./data/customer_data.xlsx')

# Find top customer
# Ensure required columns exist (fallback to existing notebook `data` variable)
if not {'Customer', 'Amount'}.issubset(df.columns):
    df = pd.DataFrame(data)

customer_totals = df.groupby('Customer')['Amount'].sum()
top_customer = customer_totals.idxmax()
top_amount = df.groupby('Customer')['Amount'].sum().max()

print("Top customer:", top_customer)
print("Total amount bought:", top_amount)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 7
#       3 # Read the Excel file (adjust path if needed)
#       4 df = pd.read_excel('./data/customer_data.xlsx')
#       5
#       6 # Find top customer
# ----> 7 top_customer = df.groupby('Customer')['Amount'].sum().idxmax()
#       8 top_amount = df.groupby('Customer')['Amount'].sum().max()
#       9
#      10 print("Top customer:", top_customer)
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9179
#    9180         if level is None and by is None:
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#    9186             axis=axis,
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Customer'

# %%
# Excel read/write example
excel_path = './data/dummy_students.csv'
df_csv.to_excel(excel_path, index=False)
df_excel = pd.read_excel(excel_path)
print(df_excel.head())
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\_config\config.py:132, in _get_single_key(pat, silent)
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel.csv.writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 # Excel read/write example
#       2 excel_path = './data/dummy_students.csv'
# ----> 3 df_csv.to_excel(excel_path, index=False)
#       4 df_excel = pd.read_excel(excel_path)
#       5 print(df_excel.head())
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2413             index_label=index_label,
#    2414             merge_cells=merge_cells,
#    2415             inf_rep=inf_rep,
#    2416         )
# -> 2417         formatter.write(
#    2418             excel_writer,
#    2419             sheet_name=sheet_name,
#    2420             startrow=startrow,
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\PMLS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1140, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1138             engine = get_default_engine(ext, mode="writer")
#    1139     except KeyError as err:
# -> 1140         raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1142 # for mypy
#    1143 assert engine is not None
#
# ValueError: No engine for filetype: 'csv'

# %% [markdown]
# ## 3. Data Exploration
#
# Data load hone ke baad in methods se dataset ko quickly inspect kiya jata hai:
# - `head()` aur `tail()` for sample rows
# - `info()` for columns, data types, aur missing values
# - `describe()` for summary statistics
#
# Ye checks data quality aur structure samajhne ke liye useful hote hain.

# %%
print(pd.options.display.min_rows)
print(pd.options.display.max_rows)

#In my system the number is 60, which means that if the DataFrame contains more than 60 rows, the print(df) statement will return only the headers and the first and last 5 rows.
# Out:
# 10
# 60

# %%
# Data Exploration
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  5 non-null      int64
#  1   Name       5 non-null      object
#  2   Age        5 non-null      int64
#  3   Grade      5 non-null      object
#  4   City       5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes

# %% [markdown]
# ### Understanding `df.info()` in Pandas
#
# The `df.info()` method in Pandas provides a concise summary of a DataFrame, which helps us quickly understand the structure and content of the dataset.
#
#
# **What `df.info()` tells us:**
#
# 1. **Type of object**: `<class 'pandas.core.frame.DataFrame'>` shows that this is a Pandas DataFrame.
# 2. **Index range**: `RangeIndex: 5 entries, 0 to 4` indicates 5 rows with indices from 0 to 4.
# 3. **Columns info**:
#
#    * Column names (`StudentID`, `Name`, `Age`, `Grade`, `City`)
#    * Number of non-null entries in each column (`5 non-null` means no missing values)
#    * Data type of each column (`int64` for numbers, `object` for text)
# 4. **Data types summary**: `dtypes: int64(2), object(3)` shows there are 2 numeric columns and 3 object (text) columns.
# 5. **Memory usage**: `memory usage: 332.0+ bytes` shows the memory consumed by the DataFrame.
#
# **Why we use it:**
#
# * Quickly check the structure of the dataset.
# * Identify missing values.
# * Understand data types for analysis or preprocessing.
# * Optimize memory usage if working with large datasets.
#
# ---
#
# This method is essential for **initial data exploration** to understand what kind of data we are working with before analysis.

# %%
print(df_csv.describe())
# Out:
#         StudentID        Age
# count    5.000000   5.000000
# mean   103.000000  20.400000
# std      1.581139   1.140175
# min    101.000000  19.000000
# 25%    102.000000  20.000000
# 50%    103.000000  20.000000
# 75%    104.000000  21.000000
# max    105.000000  22.000000

# %% [markdown]
# # Understanding df.describe()
#
# `df.describe()` gives a quick summary of your dataset, showing count, mean, standard deviation, min, max, and quartiles.
#
# It helps you understand the basic stats of your data in just a glance, like average age, range, and distribution.

# %%
print(df.head(3))

# %%
print(df.tail(2))

# %% [markdown]
# ## 4. Indexing & Selection
#
# Pandas mein rows aur columns ko select karne ke liye different methods use hote hain:
# - `df['col']` for a single column
# - `df[['col1', 'col2']]` for multiple columns
# - `iloc` for position-based selection
# - `loc` for label-based selection
# - boolean filtering for specific conditions

# %%
# Indexing & Filtering
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df[['Name','Age']])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
print(df.iloc[1])
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
df_indexed = df.set_index('Name')
print(df_indexed.loc['Alice'])
# Out:
# Age           25
# City    New York
# Name: Alice, dtype: object

# %%
print(df[df['Age'] > 30])
# Out:
#       Name  Age     City
# 2  Charlie   35  Chicago
# 3    David   40  Houston

# %%
# Value in first row, 'City' column
print(df.loc[0, 'City'])

# %%
# Rows where Name is 'Sara'
print(df.loc[df['Name'] == 'Sara'])

# %% [markdown]
# # sorting

# %%
# Sorting, Grouping & Merging
print(df.sort_values(by='Age'))
# Out:
#       Name  Age         City  Salary
# 0    Alice   26     New York   50000
# 1      Bob   31  Los Angeles   60000
# 2  Charlie   36      Chicago   70000
# 3    David   41      Houston   80000

# %%
print(df.sort_values(by='Name', ascending=False))
# Out:
#       Name  Age         City  Salary
# 3    David   41      Houston   80000
# 2  Charlie   36      Chicago   70000
# 1      Bob   31  Los Angeles   60000
# 0    Alice   26     New York   50000

# %%
import pandas as pd

s = pd.Series([30, 10, 40, 20])
print("Original Series:\n", s)

# Sort ascending
s_sorted = s.sort_values()
print("\nSorted Series (Ascending):\n", s_sorted)

# Sort descending
s_sorted_desc = s.sort_values(ascending=False)
print("\nSorted Series (Descending):\n", s_sorted_desc)
# Out:
# Original Series:
#  0    30
# 1    10
# 2    40
# 3    20
# dtype: int64
#
# Sorted Series (Ascending):
#  1    10
# 3    20
# 0    30
# 2    40
# dtype: int64
#
# Sorted Series (Descending):
#  2    40
# 0    30
# 3    20
# 1    10
# dtype: int64

# %%
data = {'Name': ['Ali', 'Sara', 'Ahmed'], 'Age':[20, 22, 19], 'Score':[85, 90, 80]}
df = pd.DataFrame(data)
print("Original DataFrame:\n", df)

# Sort by single column
df_sorted_age = df.sort_values(by='Age')
print("\nSorted by Age:\n", df_sorted_age)

# Sort by multiple columns
df_sorted_age_score = df.sort_values(by=['Age', 'Score'], ascending=[True, False])
print("\nSorted by Age ascending, Score descending:\n", df_sorted_age_score)
# Out:
# Original DataFrame:
#      Name  Age  Score
# 0    Ali   20     85
# 1   Sara   22     90
# 2  Ahmed   19     80
#
# Sorted by Age:
#      Name  Age  Score
# 2  Ahmed   19     80
# 0    Ali   20     85
# 1   Sara   22     90
#
# Sorted by Age ascending, Score descending:
#      Name  Age  Score
# 2  Ahmed   19     80
# 0    Ali   20     85
# 1   Sara   22     90

# %% [markdown]
# ## 6. Groupby & Aggregation
#
# `groupby()` data ko groups mein split karta hai aur phir har group par summary calculation karta hai.
# Aksar use hone wale aggregations:
# - mean
# - sum
# - count
# - min / max

# %%
df_group = pd.DataFrame({
    'Department': ['HR', 'IT', 'HR', 'IT'],
    'Salary': [50000, 60000, 55000, 65000],
    'Employee': ['A', 'B', 'C', 'D']
})

print(df_group.groupby('Department')['Salary'].mean())
print(df_group.groupby('Department').agg(average_salary=('Salary', 'mean'), employee_count=('Employee', 'count')))
# Out:
# Department
# HR    52500.0
# IT    62500.0
# Name: Salary, dtype: float64
#             average_salary  employee_count
# Department
# HR                 52500.0               2
# IT                 62500.0               2

# %% [markdown]
# ## 7. Merging & Joining DataFrames
#
# Multiple DataFrames ko combine karne ke liye `merge()` use hota hai.
# Common join types:
# - `inner`
# - `left`
# - `right`
# - `outer`
#
# Join type choose karne se output rows ka behavior control hota hai.

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['A', 'B', 'C']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Score': [90, 95, 85]})

merged_inner = pd.merge(df1, df2, on='ID', how='inner')
merged_left = pd.merge(df1, df2, on='ID', how='left')

print('Inner join:')
print(merged_inner)
print('\nLeft join:')
print(merged_left)
# Out:
# Inner join:
#    ID Name  Score
# 0   2    B     90
# 1   3    C     95
#
# Left join:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B   90.0
# 2   3    C   95.0

# %%
# Saving Data
df.to_csv('output.csv', index=False)
df.to_json('output.json', orient='records')

# %% [markdown]
# **Assignment:**
#
# 1. Create a Pandas Series with values `[50, 20, 40, 10, 30]` and sort it in ascending order.
# 2. Create a DataFrame with columns `Name = ['Ali','Sara','Ahmed','Zara']` and `Score = [85, 95, 80, 90]`. Sort the DataFrame by `Score` descending.
# 3. Print both sorted outputs.
#
# **Expected Output:**
#
# ```python
# # Series ascending: 10, 20, 30, 40, 50
#
# # DataFrame sorted by Score descending:
# #    Name  Score
# # 1  Sara     95
# # 3  Zara     90
# # 0   Ali     85
# # 2  Ahmed    80
# ```

# %% [markdown]
# Great! Here are **2 more mini exercises** for students, keeping them short and focused on Pandas basics like sorting and selection:
#
# ---
#
# **Exercise 2:**
#
# * Create a DataFrame:
#
# ```python
# data = {'City':['London','Paris','Tokyo','Dubai'], 'Population':[9000000, 2140000, 13960000, 3330000]}
# ```
#
# * Sort the DataFrame by `Population` in ascending order.
# * Select and print only the `City` column of the sorted DataFrame.
#
# **Expected Output:**
#
# ```python
# # City
# # 1    Paris
# # 3     Dubai
# # 0    London
# # 2     Tokyo
# ```
#
# ---
#
# **Exercise 3:**
#
# * Create a Series with values `[5, 2, 9, 1, 7]`.
# * Sort the Series descending and select the top 3 values only.
# * Print the result.
#
# **Expected Output:**
#
# ```python
# # 2    9
# # 4    7
# # 0    5
# ```

# %%
import pandas as pd

# Sample data
data = {'Customer':['Ali','Sara','Ali','Ahmed','Sara','Ali'],
        'Amount':[100,200,150,300,250,50]}
df = pd.DataFrame(data)

# Find the customer who bought the most
top_customer = df.groupby('Customer')['Amount'].sum().idxmax()
print("Top customer:", top_customer)
# Out:
# Top customer: Sara
