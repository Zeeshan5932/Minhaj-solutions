# %% [markdown]
# # Matplotlib & Seaborn Visualization Practice
# ## Dataset: Titanic Dataset
#
# This notebook is designed for beginners who have completed Pandas basics and now want to start data visualization.
#
# We will load the Titanic dataset using **Seaborn** and create **20+ different graphs** using **Matplotlib** and **Seaborn**.
#
# ### What students will learn
# - How to create basic graphs
# - How to label charts properly
# - How to understand chart output
# - How to compare categorical and numerical data
# - How to use visualization for simple data analysis

# %% [markdown]
# ## Cell 1: Import Required Libraries
#
# First, we import the required Python libraries.
#
# - `pandas` is used for data handling.
# - `numpy` is used for numerical operations.
# - `matplotlib.pyplot` is used for creating graphs.
# - `seaborn` is used for advanced and attractive statistical graphs.

# %%
pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# This setting makes charts look cleaner
sns.set_theme(style="whitegrid")

# This command helps charts display inside Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Cell 2: Load Titanic Dataset Using Seaborn
#
# Seaborn has some built-in practice datasets. Here we load the Titanic dataset.
#
# This dataset contains passenger information such as age, gender, ticket class, fare, and survival status.

# %%
df = sns.load_dataset('titanic')

# Display first 5 rows
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### 1. `survived`
#
# * Value `1` = Passenger survived, `0` = Passenger did not survive.
# * **Story:** “Did this person make it alive after the ship sank?”
#
# ### 2. `pclass`
#
# * Passenger class: `1` = First class, `2` = Second class, `3` = Third class.
# * **Story:** “Which cabin class did this passenger travel in?”
#
# ### 3. `sex`
#
# * Gender: `male` or `female`.
# * **Story:** “Is this passenger a man or a woman?”
#
# ### 4. `age`
#
# * Age of the passenger in years.
# * **Story:** “How old was this passenger?”
#
# ### 5. `sibsp`
#
# * Number of siblings or spouses aboard.
# * **Story:** “Did they travel with brothers, sisters, or spouse?”
#
# ### 6. `parch`
#
# * Number of parents or children aboard.
# * **Story:** “Did they travel with parents or children?”
#
# ### 7. `fare`
#
# * Ticket price paid by passenger.
# * **Story:** “How much did this passenger pay for the ticket?”
#
# ### 8. `embarked`
#
# * Port of boarding: `C` = Cherbourg, `Q` = Queenstown, `S` = Southampton.
# * **Story:** “Where did they get on the ship?”
#
# ### 9. `class`
#
# * Text version of `pclass`: `First`, `Second`, `Third`.
# * **Story:** “Passenger’s class in words.”
#
# ### 10. `who`
#
# * Broader category: `man`, `woman`, `child`.
# * **Story:** “Is this passenger an adult man, woman, or child?”
#
# ### 11. `adult_male`
#
# * Boolean `True`/`False`: Adult male or not.
# * **Story:** “Quick check: is this an adult male?”
#
# ### 12. `deck`
#
# * Deck of the ship (A–G) if known.
# * **Story:** “Which deck was this passenger staying on?”
#
# ### 13. `embark_town`
#
# * Full name of boarding town.
# * **Story:** “City where they boarded the Titanic.”
#
# ### 14. `alive`
#
# * Text version of `survived`: `yes` or `no`.
# * **Story:** “Did they survive? (human-friendly text)”
#
# ### 15. `alone`
#
# * Boolean `True`/`False`: Passenger traveling alone.
# * **Story:** “Did this passenger have no family onboard?”
#
# ---
#
# ### Mini
#
# > “This is a 22-year-old male in third class, traveling with 1 sibling, boarded at Southampton, paid $7.25, traveling alone. He did **not survive**.”
#
# ---

# %% [markdown]
# ## Matplotlib & Seaborn Charts in Titanic Notebook
#
# Here is a summary of the charts used in the notebook, categorized by **categorical** and **numerical** usage.
#
# | Chart Type   | Columns Used                                     | Data Type               | Purpose                                                                   |
# | ------------ | ------------------------------------------------ | ----------------------- | ------------------------------------------------------------------------- |
# | Count Plot   | `Sex`, `Pclass`, `Embarked`, `Survived`          | Categorical             | Shows counts/frequency of categories                                      |
# | Bar Plot     | `Pclass` vs `Survived`, `Embarked` vs `Survived` | Categorical             | Compare category values across another categorical/numerical target       |
# | Box Plot     | `Age` vs `Pclass`, `Fare` vs `Survived`          | Numerical               | Shows distribution, median, quartiles, outliers                           |
# | Violin Plot  | `Age` vs `Pclass`, `Fare` vs `Sex`               | Numerical               | Similar to box plot but shows density distribution                        |
# | Histogram    | `Age`, `Fare`                                    | Numerical               | Distribution of single numerical variable                                 |
# | KDE Plot     | `Age`, `Fare`                                    | Numerical               | Smoothed density plot of a numerical variable                             |
# | Scatter Plot | `Age` vs `Fare`                                  | Numerical               | Shows relationship between two numerical variables                        |
# | Joint Plot   | `Age` vs `Fare`                                  | Numerical + Categorical | Combines scatter with histogram/KDE for numerical relationship            |
# | Pair Plot    | `Age`, `Fare`, `Pclass`                          | Numerical + Categorical | Pairwise scatterplots for multiple numerical columns, hue for categorical |
# | Swarm Plot   | `Age` vs `Pclass`                                | Numerical + Categorical | Shows all points distribution for categorical groups                      |
# | Heatmap      | Correlation matrix                               | Numerical               | Shows correlation strength between numerical variables                    |
# | Line Plot    | `Age` vs `Survived` counts (aggregated)          | Numerical               | Trends over ordered data                                                  |
# | Area Plot    | `Survived` counts over `Pclass`                  | Categorical             | Cumulative distribution of numerical counts across categories             |
# | Pie Chart    | `Survived`                                       | Categorical             | Shows proportion of categories                                            |
# | LM Plot      | `Age` vs `Fare`, hue=`Sex`                       | Numerical + Categorical | Regression line between numerical variables with category separation      |
# | Facet Grid   | `Age` vs `Fare` split by `Sex`                   | Numerical + Categorical | Multiple plots for each category                                          |
#
# **Notes for Students:**
#
# * **Categorical charts** are mainly: Count Plot, Bar Plot, Pie Chart, Facet Grid (for categories).
# * **Numerical charts** are mainly: Histogram, KDE, Box Plot, Violin Plot, Scatter, Joint, Pair, Swarm, Line, Area, LM Plot, Heatmap.
# * Some charts combine both types, e.g., `Box Plot` with numerical on y-axis and categorical on x-axis.
# * Always choose chart type based on the **data type** of your column(s).

# %% [markdown]
# ## Cell 3: Basic Dataset Information
#
# Before creating graphs, we should understand the dataset.
#
# - `shape` tells rows and columns.
# - `info()` shows column names, missing values, and data types.
# - `isnull().sum()` shows missing values in each column.

# %%
print("Dataset Shape:", df.shape)
print("Dataset Info:")
df.info()

print("Missing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (891, 15)
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# Missing Values:
# ...

# %% [markdown]
# ## Cell 4: Simple Data Cleaning for Visualization
#
# For visualization, we handle a few missing values:
#
# - Missing `age` values are filled with the median age.
# - Missing `embarked` values are filled with the most common value.
# - Missing `deck` values are filled with `Unknown`.
#
# This step makes the dataset easier to visualize.

# %%
df_clean = df.copy()

df_clean['age'] = df_clean['age'].fillna(df_clean['age'].median())
df_clean['embarked'] = df_clean['embarked'].fillna(df_clean['embarked'].mode()[0])
df_clean['deck'] = df_clean['deck'].cat.add_categories('Unknown').fillna('Unknown')

print("Missing values after basic cleaning:")
print(df_clean.isnull().sum())
# Out:
# Missing values after basic cleaning:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## Graph 1: Line Plot - Passenger Index vs Fare
#
# A line plot connects data points with a line. Here we use it to see how passenger fares change across passenger index numbers. This is mainly for learning line plot syntax.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(10,5))
plt.plot(df_clean.index[:100], df_clean['fare'].head(100), marker='o')
plt.title('Line Plot: First 100 Passenger Fares')
plt.xlabel('Passenger Index')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ## Graph 2: Bar Chart - Average Fare by Class
#
# A bar chart compares values between categories. Here we compare the average fare paid by passengers in First, Second, and Third class.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
avg_fare_class = df_clean.groupby('class')['fare'].mean()

plt.figure(figsize=(8,5))
plt.bar(avg_fare_class.index.astype(str), avg_fare_class.values)
plt.title('Average Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Average Fare')
plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2944\510794735.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_fare_class = df_clean.groupby('class')['fare'].mean()

# %% [markdown]
# ## Graph 3: Horizontal Bar Chart - Average Age by Class
#
# A horizontal bar chart is useful when category names are long or when we want a different layout. Here it shows average passenger age by class.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
avg_age_class = df_clean.groupby('class')['age'].mean()

plt.figure(figsize=(8,5))
plt.bar(avg_age_class.index.astype(str), avg_age_class.values)
plt.title('Average Age by Passenger Class')
plt.xlabel('Average Age')
plt.ylabel('Passenger Class')
plt.show()
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_2944\4281827493.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_age_class = df_clean.groupby('class')['age'].mean()

# %% [markdown]
# ## Graph 4: Histogram - Age Distribution
#
# A histogram shows the distribution of numerical data. Here it shows how passenger ages are spread in the Titanic dataset.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
plt.hist(df_clean['age'], bins=20)
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ## Graph 5: Histogram with Seaborn - Fare Distribution
#
# Seaborn histogram gives a clean view of numerical distribution. Here we check how ticket fares are distributed.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
print("Total passengers:", len(df_clean))
# or
print("Total passengers:", df_clean.shape[0])
# Out:
# Total passengers: 891
# Total passengers: 891

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df_clean, x='fare', bins=30)
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Graph 6: KDE Plot - Age Density
#
# A KDE plot shows a smooth curve of data distribution. It helps us understand where most values are concentrated.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data=df_clean, x='age', fill=True)
plt.title('Age Density Plot')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Most passengers were young adults around 25 years, fewer children and elderly.”

# %% [markdown]
# ## Graph 7: Count Plot - Survival Count
#
# A count plot shows the frequency of categories. Here it shows how many passengers survived and how many did not.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df_clean, x='survived')
plt.title('Survival Count')
plt.xlabel('Survived: 0 = No, 1 = Yes')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ## Graph 8: Count Plot - Passenger Class Count
#
# This count plot shows how many passengers were in each class. It helps us understand category distribution.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df_clean, x='class')
plt.title('Passenger Count by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Most passengers traveled in Third Class, fewer in First and Second Class.”

# %% [markdown]
# ## Graph 9: Count Plot with Hue - Survival by Gender
#
# The `hue` parameter adds another category to the chart. Here we compare survival counts for male and female passengers.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df_clean, x='sex', hue='survived')
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Graph 10: Bar Plot - Survival Rate by Gender
#
# A bar plot can show average values. Since `survived` is 0 or 1, its mean gives survival rate. Here we compare survival rate by gender.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_clean, x='sex', y='survived')
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# Females had much higher chances of surviving than males.

# %% [markdown]
# ## Graph 11: Bar Plot - Survival Rate by Class
#
# This graph shows which passenger class had a higher survival rate. It is useful for comparing categories with a numerical target.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_clean, x='class', y='survived')
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# ## Graph 12: Scatter Plot - Age vs Fare
#
# A scatter plot shows the relationship between two numerical columns. Here we check whether age and fare have any visible pattern.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_clean, x='age', y='fare')
plt.title('Scatter Plot: Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ## Graph 13: Scatter Plot with Hue - Age vs Fare by Survival
#
# This scatter plot uses color grouping through `hue`. It helps compare survived and non-survived passengers in the same graph.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df_clean, x='age', y='fare', hue='survived')
plt.title('Age vs Fare by Survival')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ## Graph 14: Box Plot - Age by Class
#
# A box plot shows median, spread, and outliers. Here we compare passenger age distribution across classes.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df_clean, x='class', y='age')
plt.title('Age Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Graph 15: Box Plot - Fare by Class
#
# This box plot shows fare distribution across passenger classes. It also helps identify outliers in ticket fares.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df_clean, x='class', y='fare')
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ![ChatGPT Image May 12, 2026, 04_46_11 PM.png](<attachment:ChatGPT Image May 12, 2026, 04_46_11 PM.png>)

# %% [markdown]
# ## Graph 16: Heatmap - Correlation Matrix
#
# A heatmap shows values using color intensity. Here it shows correlation between numerical columns. Correlation tells how strongly two columns are related.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
numeric_cols = df_clean.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_cols.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Graph 17: Pie Chart - Gender Distribution
#
# A pie chart shows parts of a whole. Here we show the percentage of male and female passengers.
#
# ### Student Explanation
# Run the code and observe the chart. Ask students what the x-axis shows, what the y-axis shows, and what pattern they can see.

# %%
gender_counts = df_clean['sex'].value_counts()

plt.figure(figsize=(7,7))
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# ## Final Practice Task for Students
#
# Now students should create their own visual analysis using the Titanic dataset.
#
# ### Task
# Create at least 8 graphs:
#
# 1. Count plot of `sex`
# 2. Count plot of `class`
# 3. Histogram of `age`
# 4. Histogram of `fare`
# 5. Box plot of `age` by `class`
# 6. Bar plot of survival rate by `sex`
# 7. Scatter plot of `age` vs `fare`
# 8. Heatmap of numerical correlations
#
# ### Submission
# Students should submit:
# - Jupyter Notebook file
# - Short explanation under each graph
# - Final 5-line conclusion about Titanic passenger survival patterns

# %% [markdown]
# ## Final Conclusion
#
# In this notebook, we learned how visualization helps us understand data quickly.
#
# ### Key Points
# - Count plots show category frequency.
# - Histograms show numerical distribution.
# - Scatter plots show relationships between two numerical columns.
# - Box plots show spread and outliers.
# - Heatmaps show correlation between numerical columns.
# - Bar plots help compare averages or rates across categories.
#
# Visualization is important before machine learning because it helps us understand patterns, missing values, outliers, and relationships in the dataset.
