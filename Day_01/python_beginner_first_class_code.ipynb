# %% [markdown]
# # Introduction to Python Programming
#
# Beginner-friendly practice notebook for first Python class.
#
# **Goal:** Learn `print()`, variables, simple math, and `input()` through fun examples.

# %% [markdown]
# ## 1. Apna Introduction Program

# %%
print("My name is Ali")
# Out:
# My name is Ali

# %%
print("I am learning Python")
# Out:
# I am learning Python

# %%
print("I am from Lahore")
# Out:
# I am from Lahore
# I am learning Python

# %% [markdown]
# ## 2. Funny Message Generator

# %%
print("I love Biryani")
print("Python is easier than I expected")
print("Today I will write my first code")

# %% [markdown]
# ## 3. Dream Job Program

# %%
print("I will become a Data Scientist")
print("I will become an AI Engineer")
print("I will build my own software")

# %% [markdown]
# ## 4. Three Lines Story

# %%
print("Once I started learning Python")
print("At first, it looked difficult")
print("But after practice, it became easy and fun")

# %% [markdown]
# ## 5. Calculator Intro: Simple Sum

# %%
a = 5
b = 6

print(a-b)
# Out:
# -1

# %% [markdown]
# ## 6. Age in Future

# %%
age = 20
print("your age is" , age)
print(age - 10)
# Out:
# your age is 20
# 10

# %% [markdown]
# ## 7. Favorite Things List

# %%
print("My favorite food is Pizza")
print("My favorite game is Cricket")
print("My favorite subject is Computer Science")
# Out:
# My favorite food is Pizza
# My favorite game is Cricket
# My favorite subject is Computer Science

# %% [markdown]
# ## 8. Greeting Program Using Input

# %%
name = input("Enter your name: ")

print("Hello", name)

# %% [markdown]
# ## 9. Mood Checker

# %%
mood = input("How are you feeling today? ")

print("Oh, you are feeling", mood)

# %% [markdown]
# ## 10. Simple Guess Number Game

# %%
print("Guess a number between 1 and 5")

guess = input("Enter your guess: ")

print("You guessed:", guess)
print("Nice try!")

# %% [markdown]
# ## Bonus Practice: Better Guess Number Game

# %%
secret_number = 3

guess = int(input("Guess a number between 1 and 5: "))

if guess == secret_number:
    print("Correct! You won the game")
else:
    print("Wrong guess. Try again")

# %% [markdown]
# ## Bonus Practice: Student Custom Task

# %%
# Change the values below and run the code

student_name = "Ali"
city = "Lahore"
dream_job = "AI Engineer"

print("My name is", student_name)
print("I am from", city)
print("My dream job is", dream_job)
